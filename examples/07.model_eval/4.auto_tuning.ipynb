# %% [markdown]
# ## 🤖 Automated Tuning: Scikit-Learn GridSearchCV
# For production workflows, scikit-learn provides built-in tools that combine hyperparameter search with cross-validation.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define the model
dt_clf = DecisionTreeClassifier(random_state=42)

# Define the parameter grid (dictionary)
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [3, 5, 10, 20, None],
    'min_samples_split':
}

# Initialize GridSearchCV (cv=5 means 5-fold cross-validation)
grid_search = GridSearchCV(
    estimator=dt_clf, 
    param_grid=param_grid, 
    cv=5, 
    scoring='accuracy',
    n_jobs=-1 # Use all available CPU cores
)

# Fit the grid search (this automatically handles the k-fold looping)
grid_search.fit(X_train, y_train)

print(f"Best Cross-Validation Accuracy: {grid_search.best_score_:.4f}")
print(f"Optimal Hyperparameters: {grid_search.best_params_}")
