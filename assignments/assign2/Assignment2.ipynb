# %% [markdown]
# # Assignment 2, Due by 9am Sunday, 12 April 2026
#
# ### Name: \_\_\_\_\_\_\_\_\_\_\_\_           Student ID: \_\_\_\_\_\_\_\_\_\_\_\_

# %% [markdown]
# ### Submission Instructions
# Submit to your GitHub repository under assign2 subfolder:
# 1. The PDF file named `tree.pdf` (manual decision tree construction for Q1)
# 2. This Jupyter Notebook with all code cells executed and outputs visible

# %% [markdown]
# # Part 1 — Decision Trees (60 pts)

# %% [markdown]
# **Q1** [30 pts] Manually construct a decision tree for the **Approve Loan** dataset below using pen and paper (or any drawing tool).
#
# - **[24 pts]** Show the steps of the algorithm and compute the split criterion (Gini Impurity or Entropy) for every feature at every internal node. Show all calculations clearly.
# - **[3 pts]** Draw the final decision tree neatly with class labels at each leaf.
# - **[3 pts]** Use your tree to predict the class for the two instances below.
#   - **Instance A:** Age=Young, Income=High, Own_Home=No, Credit_History=Fair
#   - **Instance B:** Age=Senior, Income=Low, Own_Home=Yes, Credit_History=Poor
#
# Submit a PDF named `tree.pdf` containing all your work.
#
# | Age       | Income | Own_Home | Credit_History | Approve_Loan |
# |-----------|--------|----------|----------------|--------------|
# | Young     | High   | Yes      | Good           | Yes          |
# | Young     | High   | No       | Good           | No           |
# | Middle    | High   | Yes      | Good           | Yes          |
# | Senior    | Medium | No       | Good           | Yes          |
# | Senior    | Low    | Yes      | Fair           | Yes          |
# | Senior    | Low    | No       | Fair           | No           |
# | Middle    | Low    | Yes      | Fair           | Yes          |
# | Young     | Medium | No       | Fair           | No           |
# | Young     | Low    | Yes      | Good           | Yes          |
# | Senior    | Medium | Yes      | Fair           | Yes          |
# | Young     | Medium | Yes      | Poor           | No           |
# | Middle    | Medium | No       | Good           | Yes          |
# | Middle    | High   | Yes      | Poor           | Yes          |
# | Senior    | Medium | No       | Poor           | No           |
# | Young     | Low    | No       | Poor           | No           |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import (accuracy_score, confusion_matrix,
                             ConfusionMatrixDisplay, classification_report)
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# **Q2** [5 pts] Load `dataset.csv` into a Pandas DataFrame and preprocess it.
#
# - **[3 pts]** Encode the target variable using `LabelEncoder`.
# - **[2 pts]** Encode the features using `OneHotEncoder` (set `sparse_output=False`).
# - Display the first 5 rows of the preprocessed DataFrame.

# %%
# Your code here

# %% [markdown]
# **Q3** [5 pts] Train and evaluate a Decision Tree classifier.
#
# - **[1 pt]** Split the data into 80% training / 20% testing (`random_state=42`).
# - **[1 pt]** Train a `DecisionTreeClassifier` with default parameters.
# - **[2 pts]** Visualize the trained tree.
# - **[1 pt]** Report the training accuracy and testing accuracy.

# %%
# Your code here

# %% [markdown]
# **Q4** [6 pts] Evaluate the trained model on the test set.
#
# - **[1 pt]** Display the confusion matrix.
# - **[2 pts]** Print the classification report (precision, recall, F1-score).
# - **[3 pts]** Interpretation: Which class is harder to predict and why? Is the model overfitting? Justify with evidence from the metrics above.

# %%
# Your code here

# %% [markdown]
# **Q5** [8 pts] Investigate the effect of tree depth on generalization.
#
# - **[3 pts]** Train `DecisionTreeClassifier` models with `max_depth` ∈ {2, 4, 6, 8, None}. Record the training and testing accuracy for each.
# - **[3 pts]** Plot both curves (training & testing accuracy vs. max_depth) on the same graph with labels and legend.
# - **[2 pts]** Which depth gives the best bias-variance trade-off? Explain briefly.

# %%
# Your code here

# %% [markdown]
# **Q6** [6 pts] Train and compare a Random Forest model.
#
# - **[2 pts]** Train a `RandomForestClassifier`. Experiment with `n_estimators` ∈ {50, 100, 200} and `max_features` ∈ {'sqrt', 'log2'}. Report the best combination based on test accuracy.
# - **[2 pts]** Run 5-fold cross-validation on the best Random Forest. Report the fold accuracies, mean, and standard deviation.
# - **[2 pts]** Compare the Random Forest to the best Decision Tree from Q5. Which generalizes better and why?

# %%
# Your code here

# %% [markdown]
# ---
#
# # Part 2 — kNN Classification (40 pts)
#
# ## Objective
# Explore how different hyperparameters affect kNN classifier performance. You will:
# 1. Split data into training, validation, and testing sets.
# 2. Compare distance metrics: Euclidean (L2) vs. Manhattan (L1).
# 3. Perform a grid search over k and the distance metric to find optimal hyperparameters.
# 4. Evaluate the final tuned model on unseen data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.datasets import make_circles

# %% [markdown]
# ## Load the Dataset
# The code below generates a **Two Circles** dataset with structured noise injected to make classification harder. This step is provided for you — just run the cell.

# %%
X, y = make_circles(n_samples=1000, noise=0.15, factor=0.5, random_state=37)

np.random.seed(21)
X_aug = X.tolist()
y_aug = y.tolist()

n_clusters = 15

for _ in range(n_clusters):
    idx = np.random.randint(0, len(X))
    base_point = X[idx]
    base_label = y[idx]

    new_label = 1 - base_label

    n_new_points = np.random.randint(5, 9)

    for _ in range(n_new_points):
        new_point = base_point + np.random.normal(scale=0.15, size=2)
        X_aug.append(new_point)
        y_aug.append(new_label)

X_aug = np.array(X_aug)
y_aug = np.array(y_aug)

print("Original dataset size:", X.shape[0])
print("Augmented dataset size:", X_aug.shape[0])

# %% [markdown]
# ## Visualize the Dataset

# %%
# Your code here
plt.figure(figsize=(8, 8))
plt.scatter(X_aug[y_aug == 0, 0], X_aug[y_aug == 0, 1],
            c='steelblue', label='Class 0', alpha=0.6, edgecolors='k', linewidths=0.3, s=20)
plt.scatter(X_aug[y_aug == 1, 0], X_aug[y_aug == 1, 1],
            c='coral', label='Class 1', alpha=0.6, edgecolors='k', linewidths=0.3, s=20)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Two Circles Dataset (Augmented with Noise)')
plt.legend()
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 1: Split the Dataset (4 pts)
# Split the data into **three** sets:
# - **70%** Training
# - **15%** Validation
# - **15%** Testing
#
# Use `random_state=42` for all splits. Print the shapes to verify.

# %%
# Your code here

# %% [markdown]
# ## Step 2: kNN with k=5 and Euclidean Distance (4 pts)
# - **[3 pt]** Train a kNN classifier with `n_neighbors=5` and `p=2` (Euclidean).
# - **[1 pt]** Predict on the **test** set. Print the accuracy.

# %%
# Your code here

# %% [markdown]
# ## Step 3: kNN with k=5 and Manhattan Distance (4 pts)
# - **[2 pt]** Train a kNN classifier with `n_neighbors=5` and `p=1` (Manhattan).
# - **[1 pt]** Predict on the **test** set. Print the accuracy.
# - **[1 pt]** Compare results with step 2 and interpret.

# %%
# Your code here

# %% [markdown]
# ## Step 4: Hyperparameter Tuning — Grid Search (10 pts)
# - **[6 pts]** Perform a grid search over the **validation set** to find the best combination of:\
# `k` ∈ {1, 3, 5, 7, 9, 11, 15, 21, 31, 41, 51} \
# `p` ∈ {1, 2} &nbsp;(Manhattan vs. Euclidean)
#
# - **[2 pts]** Store the per-k accuracies for each distance metric (needed for Step 5).
# - **[2 pts]** Identify and print the **best (k, p)** combination and its validation accuracy.

# %%
# Your code here

# %% [markdown]
# ## Step 5: Visualization — Accuracy vs. k (8 pts)
# Plot validation accuracy as a function of k with **two curves** on the same plot:
# - One for Euclidean (`p=2`)
# - One for Manhattan (`p=1`)
#
# - **[3 pts]** Plot both accuracy curves correctly on the same figure.
# - **[1 pt]** Include a legend, axis labels, and a descriptive title.
# - **[4 pts]** In a markdown cell below your plot, describe the bias-variance behavior you observe as k increases.

# %%
# Your code here

# %% [markdown]
# ## Step 6: Final Evaluation (10 pts)
# Using the best (k, p) from Step 4:
#
# - **[2 pts]** Retrain the model on the full training data (training + validation combined).
# - **[2 pts]** Evaluate on the held-out test set and print the final test accuracy.
# - **[2 pts]** Print the full classification report.
# - **[4 pts]** In a markdown cell, compare this accuracy to Steps 2 and 3. Did hyperparameter tuning improve performance? Explain.

# %%
# Your code here
